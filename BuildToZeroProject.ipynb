# %% [markdown]
# <div class ='alert alert-success'>
#
# # **Energy Price Prediction and Thermal Storage Optimization Model Concept**
#
# </div>

# %%
#importing libraries
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as pltex

# %% [markdown]
# The following data contains energy prices from the Spanish SPOT Market, along with energy-generation data from different sources. I assumed that the energy-generation values are expressed in MegaWatt-hours (MWh)

# %%
df = pd.read_csv("20251110_MarketData.csv") #reading the csv file

# %%
df.dtypes #types of data in the file
# Out:
# datetime     object
# id            int64
# name         object
# geo_id        int64
# geo_name     object
# value       float64
# dtype: object

# %%
#conversion of datetime data into actual datetime
df['datetime'] = pd.to_datetime(
    df['datetime'],
    format='%Y-%m-%d %H:%M:%S.%f UTC',
    utc=True
)
df['datetime'] = df['datetime'].dt.floor('min') #rounding down each timestamp to the nearest minute

# %%
df.dtypes
# Out:
# datetime    datetime64[ns, UTC]
# id                        int64
# name                     object
# geo_id                    int64
# geo_name                 object
# value                   float64
# dtype: object

# %%
df
# Out:
#                        datetime   id                name  geo_id   geo_name  \
# 0     2023-12-31 23:00:00+00:00   71      Hidráulica UGH    8741  Península
# 1     2023-12-31 23:00:00+00:00  460    Previsión diaria    8741  Península
# 2     2023-12-31 23:00:00+00:00  474             Nuclear      35   Valencia
# 3     2023-12-31 23:00:00+00:00  474             Nuclear      37    Cáceres
# 4     2023-12-31 23:00:00+00:00  474             Nuclear      42  Tarragona
# ...                         ...  ...                 ...     ...        ...
# 15573 2024-01-31 22:30:00+00:00  542  Solar fotovoltaica    8741  Península
# 15574 2024-01-31 22:45:00+00:00   71      Hidráulica UGH    8741  Península
# 15575 2024-01-31 22:45:00+00:00  460    Previsión diaria    8741  Península
# 15576 2024-01-31 22:45:00+00:00  541    Previsión eólica    8741  Península
# 15577 2024-01-31 22:45:00+00:00  542  Solar fotovoltaica    8741  Península
#
#            value
# 0        626.950
# 1      21981.000
# 2       1063.900
# 3       2017.100
# 4       3032.800
# ...          ...
# 15573      0.000
# 15574   1496.925
# 15575  26566.000
# 15576   4199.000
# 15577      0.000
#
# [15578 rows x 6 columns]

# %%
# plot
Energy_type = df.name.unique()
fig = go.Figure()
for idx, data in df.groupby(['name']):
    idx_name = idx[0] if isinstance(idx, tuple) else idx
    if idx_name != 'Mercado SPOT':
        fig.add_trace(go.Scatter(
            x= data['datetime'],
            y = data['value'],
            name = str(idx_name)
        ))
    else:
        fig.add_trace(go.Scatter(
                x= data['datetime'],
                y = data['value'],
                name = str(idx_name),
                yaxis='y2'
            ))
fig.update_layout(
    xaxis_title = 'Date time',
    yaxis_title = 'Energy (MWh)',
    title = 'Energy Production From Different Sources and Energy Price',
    width = 1300,
    height = 500,
    yaxis2=dict(
        title="Mercado SPOT Price (Euro/MWh)",
        overlaying='y',
        side='right',
    ),
    legend = dict(x=1.09,y=1),
    hovermode = 'x'
)  
fig.show()

# %% [markdown]
# From the graph above, we can observe a pattern where market prices become cheaper when there is a peak in solar production. There is also an inverse correlation between market prices and wind power production. When wind power generation increases, market prices tend to decline. Conversely, when wind power production decreases, market prices begin to rise.
#
# This suggests that operation of solar plant and wind power plant lower the Energy Spot Market Price.
#
# The nuclear power, represented by the green line, shows a trough between January 17 and January 19. It is likely that two of the three nuclear generators were shut down during this period, which explains the decline in nuclear energy generation.

# %%
# plot energy price in the sport market
Energy_type = df.name.unique()
fig = go.Figure()
for idx, data in df.groupby(['name']):
    idx_name = idx[0] if isinstance(idx, tuple) else idx
    if idx_name == 'Mercado SPOT':
        fig.add_trace(go.Scatter(
            x= data['datetime'],
            y = data['value'],
            name = str(idx_name)
        ))

fig.update_layout(
    xaxis_title = 'Date time',
    yaxis_title = 'Energy Price (Euro/MWh)',
    title = 'Energy Price in the Spot Market',
    width = 1200,
    height = 400
)  
fig.show()

# %%
# Plot energy spot market prices on an hourly basis.
import warnings
plt.figure(figsize=(14,4))
warnings.filterwarnings('ignore')
MSpot = df[df['name']=='Mercado SPOT'].drop(columns=['id','geo_id','geo_name'])
MSpot.set_index('datetime', inplace=True)
MSpot['Hour'] = MSpot.index.hour
MSpot.resample('H')
sns.boxplot(MSpot,x='Hour', y='value', palette='RdBu')
plt.title('Hourly Energy SPOT Market Price')
plt.ylabel('Mercado SPOT (Euro/MWh)')
plt.show()

# %% [markdown]
# We can observe a clear pattern in the energy price: it tends to be higher in the morning and evening. This creates an opportunity to sell energy and generate profit, or to purchase energy when the price is low to minimize costs.

# %% [markdown]
# # 1. Data Exploration and Preprocessing

# %% [markdown]
# Descriptive Statistics

# %%
df.groupby('name')['value'].describe().T
# Out:
# name   Hidráulica UGH  Mercado SPOT      Nuclear  Previsión diaria  \
# count     2976.000000    744.000000  2930.000000       2976.000000
# mean      1172.488601     74.100094  1777.841433      28213.715390
# std        457.773994     27.921106   820.843067       4831.410334
# min        301.425000      0.430000   579.000000      17934.000000
# 25%        796.025000     58.500000  1003.400000      23867.000000
# 50%       1176.925000     75.950000  2012.500000      29035.500000
# 75%       1523.575000     92.682500  2017.100000      32323.500000
# max       2171.575000    168.350000  3032.800000      38313.000000
#
# name   Previsión eólica  Solar fotovoltaica
# count       2976.000000         2976.000000
# mean        7562.785618         2414.356384
# std         4397.665803         3746.842803
# min          662.000000            0.000000
# 25%         3890.000000            0.000000
# 50%         6491.500000            0.000000
# 75%        10926.000000         4357.750000
# max        18883.000000        12488.900000

# %% [markdown]
# The energy price can rise as high as 168.35 €/MWh. Conversely, it can fall to as low as 0.40 €/MWh

# %% [markdown]
# ## Trend and Seasonality

# %%
# import library to detect trends and seasonality in the price 
df_copy = df.copy()
df_copy.drop(['id','geo_name','geo_id'],inplace=True, axis=1)
df_copy.set_index('datetime',inplace=True)
df_copy.index = pd.to_datetime(df_copy.index)
df_copy['Hour'] = df_copy.index.hour
df_copy.set_index('Hour', inplace=True)
import statsmodels.tsa.seasonal as STL
df_market_price = df_copy[df_copy['name'] == 'Mercado SPOT']

ses_decomp = STL.seasonal_decompose(df_market_price['value'], model='additive', period=96)

# --- Create Subplots using MATPLOT ---
'''
fig, (ax1,ax2,ax3) = plt.subplots(3,1, figsize=(15,8))
ses_decomp.trend.plot(ax=ax1,ylabel = "trend")
ses_decomp.resid.plot(ax=ax2,ylabel = "seasoanlity")
ses_decomp.seasonal.plot(ax=ax3,ylabel = "residual")
plt.tight_layout()
plt.show() '''

import plotly.subplots as sp
# --- Create Subplots ---
fig = sp.make_subplots(
    rows=3, cols=1,
    shared_xaxes=True,
    vertical_spacing=0.08,
    subplot_titles=("Trend", "Seasonality", "Residual")
)

# Trend
fig.add_trace(
    go.Scatter(
        x=df_market_price.index,
        y=ses_decomp.trend,
        mode="lines",
        name="Trend"
    ),
    row=1, col=1
)

# Seasonality
fig.add_trace(
    go.Scatter(
        x=df_market_price.index,
        y=ses_decomp.seasonal,
        mode="lines",
        name="Seasonality"
    ),
    row=2, col=1
)

# Residual
fig.add_trace(
    go.Scatter(
        x=df_market_price.index,
        y=ses_decomp.resid,
        mode="lines",
        name="Residual"
    ),
    row=3, col=1
)

# Layout
fig.update_layout(
    height=900,
    title="Seasonal Decomposition (Additive Model)",
    showlegend=False,
    template="plotly_white"
)

fig.update_xaxes(title_text="Time", row=3, col=1)
fig.update_yaxes(title_text="Trend", row=1, col=1)
fig.update_yaxes(title_text="Seasonality", row=2, col=1)
fig.update_yaxes(title_text="Residual", row=3, col=1)

fig.show()

# %% [markdown]
# From the graph above, we can observe seasonality in the Energy Spot Market Price. Although the daily 24-hour seasonality is not perfectly consistent, a clear pattern emerges: the Energy Spot Market Price tends to increase just before noon and again in the evening.  The residual captures anomalies, outliers, and other unexpected events.

# %% [markdown]
# ## Missing Values in the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15578 entries, 0 to 15577
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  15578 non-null  datetime64[ns, UTC]
#  1   id        15578 non-null  int64
#  2   name      15578 non-null  object
#  3   geo_id    15578 non-null  int64
#  4   geo_name  15578 non-null  object
#  5   value     15578 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(2), object(2)
# memory usage: 730.3+ KB

# %%
df.isna().sum()
# Out:
# datetime    0
# id          0
# name        0
# geo_id      0
# geo_name    0
# value       0
# dtype: int64

# %%
import missingno as msno
msno.bar(df, figsize=(6,4))
# Out:
# <Axes: >

# %% [markdown]
# For the columns above, there aren't any missing values.

# %%
df.isnull().sum()
# Out:
# datetime    0
# id          0
# name        0
# geo_id      0
# geo_name    0
# value       0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset. If any missing values occur, they can be replaced using interpolation, forward fill, backward fill, etc.

# %% [markdown]
# ## Anomalies

# %%
df_value = df[['name', 'value']]
unique_names = df_value['name'].unique()
n = len(unique_names)

# Create subplots
fig, axes = plt.subplots(2, int((n + 1) / 2), figsize=(12, 6))
axes = axes.flatten()  

for i, name in enumerate(unique_names):
    subset = df_value.loc[df_value['name'] == name, 'value']
    subset.plot(kind='box', ax=axes[i], title=f'{name}')
    axes[i].set_ylabel(f" ")

plt.tight_layout()
plt.show()

# %% [markdown]
# Several data points lie outside the whiskers of the boxplot, and these are considered outliers. Based on this criterion, both Solar Photovoltaic and Mercado Spot contain outliers.

# %% [markdown]
# ## Removing Anomalies

# %% [markdown]
# Here, I used the Interquartile Range (IQR) method to remove anomalies, as illustrated in the boxplot above. Any data points that fall above the upper bound or below the lower bound are removed from the dataset.

# %%
def remove_anomalies (data_frame_, column):
    data_frame = data_frame_.copy()
    for name_ in ['Solar fotovoltaica','Mercado SPOT']:
        df_spot_market = data_frame[data_frame['name']== name_]
        Q1 = df_spot_market[column].quantile(0.25)
        Q3 = df_spot_market[column].quantile(0.75)
        IQR = Q3-Q1
        print('Quartile 1:', '|', Q1, 'Quartile 3:', Q3)
        print('Lower Bound:',Q1-1.5*IQR,'|', 'Upper Bound:', Q3+1.5*IQR)

        lower_bound = Q1 - 1.5 * IQR
        Upper_bound = Q3 + 1.5 * IQR

        Mask = (data_frame['name']==name_) & (data_frame['value']>Upper_bound) | (data_frame['name']==name_) & (data_frame['value']<lower_bound)
        data_frame.loc[Mask,'value'] = pd.NA

    return data_frame

removed_anomalies = remove_anomalies(df,'value')
# Out:
# Quartile 1: | 0.0 Quartile 3: 4357.75
# Lower Bound: -6536.625 | Upper Bound: 10894.375
# Quartile 1: | 58.5 Quartile 3: 92.6825
# Lower Bound: 7.226249999999993 | Upper Bound: 143.95625

# %%
df[df['name'] == 'Mercado SPOT'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 744 entries, 8 to 15565
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  744 non-null    datetime64[ns, UTC]
#  1   id        744 non-null    int64
#  2   name      744 non-null    object
#  3   geo_id    744 non-null    int64
#  4   geo_name  744 non-null    object
#  5   value     744 non-null    float64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(2), object(2)
# memory usage: 40.7+ KB

# %%
removed_anomalies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15578 entries, 0 to 15577
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  15578 non-null  datetime64[ns, UTC]
#  1   id        15578 non-null  int64
#  2   name      15578 non-null  object
#  3   geo_id    15578 non-null  int64
#  4   geo_name  15578 non-null  object
#  5   value     15410 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(2), object(2)
# memory usage: 730.3+ KB

# %% [markdown]
# Box Plot

# %% [markdown]
# The boxplot below illustrates the presence of outliers in the dataset. After removing the anomalies in the spot market price, the data points outside the whiskers are no longer visible.

# %%
df_value = removed_anomalies[['name','value']]
unique_names = removed_anomalies['name'].unique()
n = len(unique_names)
fig, axes = plt.subplots(2, int(n/2), figsize = (14,5))
axes = axes.flatten()
for idx, names in enumerate(unique_names):
    subset = df_value.loc[df_value['name'] ==names,'value']
    subset.plot(kind ='box', ax=axes[idx], title =f'{names}')

plt.tight_layout()
plt.show()

# %% [markdown]
# Histogram

# %%
df_value = removed_anomalies[['name','value']]
unique_names = removed_anomalies['name'].unique()
n = len(unique_names)
fig, axes = plt.subplots(2, int(n/2), figsize = (14,5))
axes = axes.flatten()
for idx, names in enumerate(unique_names):
    subset = df_value.loc[df_value['name'] ==names,'value']
    subset.plot(kind ='hist', ax=axes[idx], title =f'{names}', bins = 10, )
plt.tight_layout()
plt.show()

# %% [markdown]
# Pivot Table:
#
# I pivoted the table below because I assumed that hydropower, wind energy, nuclear energy, solar energy, predicted energy generation and the predicted wind energy generation affect the actual spot market price. According to the merit-order principle, the market clearing price is determined by the operational cost of the generation units required to meet demand. Therefore, we treat the different types of energy generation as independent variables and the spot market price as the dependent variable.

# %%
pivot = removed_anomalies.pivot_table(columns='name', index='datetime', values='value')

# Ensure index is datetime & remove timezone
pivot.index = pivot.index.strftime('%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ## Handling Missing Values

# %% [markdown]
# Is there any null values in the pivot table?

# %%
print('Null values in the table\n',pivot.isnull().sum())
print('\n--------\n')
# Out:
# Null values in the table
#  name
# Hidráulica UGH           0
# Mercado SPOT          2267
# Nuclear               2232
# Previsión diaria         0
# Previsión eólica         0
# Solar fotovoltaica     133
# dtype: int64
#
# --------

# %% [markdown]
# We see missing values in the pivoted table because the energy generation data are sampled every 15 minutes, while the actual market spot prices and nuclear energy generation are recorded hourly. In addition, the anomalies removed earlier were replaced with NaN values, which causes both the PV generation column and the market spot price column to have missing values.

# %%
Hourly_pivot = pivot.copy()

# %% [markdown]
# ## Remove null values using methods such as bfill, ffill, or fillna.

# %% [markdown]
# I assume that nuclear generation remains constant over the next 15 minutes; therefore, the forward-fill (ffill) method was used to fill the missing values.
#
# Similarly, the missing values in the solar PV generation and the actual spot market prices were also filled using the forward-fill method.

# %%
pivot['Nuclear'].ffill(inplace=True)
pivot['Mercado SPOT'].ffill(inplace=True)
pivot['Solar fotovoltaica'].ffill(inplace=True)
# Export to Excel
pivot.to_excel('pivot.xlsx')
pivot
# Out:
# name                 Hidráulica UGH  Mercado SPOT  Nuclear  Previsión diaria  \
# datetime
# 2023-12-31 23:00:00         626.950         63.33   1779.3           21981.0
# 2023-12-31 23:15:00         647.975         63.33   1779.3           21863.0
# 2023-12-31 23:30:00         625.850         63.33   1779.3           21807.0
# 2023-12-31 23:45:00         625.850         63.33   1779.3           21767.0
# 2024-01-01 00:00:00         663.125         50.09   1779.3           22640.0
# ...                             ...           ...      ...               ...
# 2024-01-31 21:45:00        1673.050         85.00   1779.3           29007.0
# 2024-01-31 22:00:00        1588.950         77.52   1779.3           28070.0
# 2024-01-31 22:15:00        1547.425         77.52   1779.3           27495.0
# 2024-01-31 22:30:00        1547.425         77.52   1779.3           27003.0
# 2024-01-31 22:45:00        1496.925         77.52   1779.3           26566.0
#
# name                 Previsión eólica  Solar fotovoltaica
# datetime
# 2023-12-31 23:00:00            5218.0                 0.0
# 2023-12-31 23:15:00            5198.0                 0.0
# 2023-12-31 23:30:00            5175.0                 0.0
# 2023-12-31 23:45:00            5147.0                 0.0
# 2024-01-01 00:00:00            5299.0                 0.0
# ...                               ...                 ...
# 2024-01-31 21:45:00            4059.0                 0.0
# 2024-01-31 22:00:00            4027.0                 0.0
# 2024-01-31 22:15:00            4090.0                 0.0
# 2024-01-31 22:30:00            4148.0                 0.0
# 2024-01-31 22:45:00            4199.0                 0.0
#
# [2976 rows x 6 columns]

# %%
pivot.isna().sum()
# Out:
# name
# Hidráulica UGH        0
# Mercado SPOT          0
# Nuclear               0
# Previsión diaria      0
# Previsión eólica      0
# Solar fotovoltaica    0
# dtype: int64

# %% [markdown]
# ## Correlation

# %%
# Calculate the correlation matrix
corr = pivot.iloc[:,:].corr(method='pearson') 

# Plot Heat Map,
f, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(corr, annot=True, fmt=".2f" )
plt.title('Correlation')
plt.show()

# %% [markdown]
# This heatmap shows a high correlation between the market spot price and the predicted energy generation and the Hydropower generation.

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# **HOUR**: At different times of the day, the intensity of solar and wind energy production varies. For instance, solar power reaches its maximum output around noon, while wind tends to blow more strongly in the evening and at night. We assume that during these peak periods of solar and wind production, their influence on the market price becomes more noticeable.
#
# **MONTH**: Similarly, due to seasonal and weather variations across different months, energy production becomes erratic and depends on the time of year. For example, summer months receive more sunlight, whereas winter months have limited sunlight.
#
# **Cyclical encoding**: Temporal features such as hours or months are cyclical, but numeric representations treat the gap between, for example, hour 23 and hour 0 as large. Encoding these features using sine and cosine preserves their cyclical nature and prevents misleading gaps.

# %%
pivot.index = pd.to_datetime(pivot.index)

# %%
# function to create temporal features

def temporal_features (dataframe):
    dataframe['Hour'] = dataframe.index.hour
    dataframe['Month'] = dataframe.index.month
    dataframe['hour_of_day'] = dataframe.index.hour / 24.0
    dataframe['hour_of_day_sin'] = np.sin(2 * np.pi * dataframe['hour_of_day'])
    dataframe['hour_of_day_cos'] = np.cos(2 * np.pi * dataframe['hour_of_day'])
    return dataframe

# %%
pivot = temporal_features(pivot)

# %%
pivot.dropna(inplace=True)
pivot
# Out:
# name                 Hidráulica UGH  Mercado SPOT  Nuclear  Previsión diaria  \
# datetime
# 2023-12-31 23:00:00         626.950         63.33   1779.3           21981.0
# 2023-12-31 23:15:00         647.975         63.33   1779.3           21863.0
# 2023-12-31 23:30:00         625.850         63.33   1779.3           21807.0
# 2023-12-31 23:45:00         625.850         63.33   1779.3           21767.0
# 2024-01-01 00:00:00         663.125         50.09   1779.3           22640.0
# ...                             ...           ...      ...               ...
# 2024-01-31 21:45:00        1673.050         85.00   1779.3           29007.0
# 2024-01-31 22:00:00        1588.950         77.52   1779.3           28070.0
# 2024-01-31 22:15:00        1547.425         77.52   1779.3           27495.0
# 2024-01-31 22:30:00        1547.425         77.52   1779.3           27003.0
# 2024-01-31 22:45:00        1496.925         77.52   1779.3           26566.0
#
# name                 Previsión eólica  Solar fotovoltaica  Hour  Month  \
# datetime
# 2023-12-31 23:00:00            5218.0                 0.0    23     12
# 2023-12-31 23:15:00            5198.0                 0.0    23     12
# 2023-12-31 23:30:00            5175.0                 0.0    23     12
# 2023-12-31 23:45:00            5147.0                 0.0    23     12
# 2024-01-01 00:00:00            5299.0                 0.0     0      1
# ...                               ...                 ...   ...    ...
# 2024-01-31 21:45:00            4059.0                 0.0    21      1
# 2024-01-31 22:00:00            4027.0                 0.0    22      1
# 2024-01-31 22:15:00            4090.0                 0.0    22      1
# 2024-01-31 22:30:00            4148.0                 0.0    22      1
# 2024-01-31 22:45:00            4199.0                 0.0    22      1
#
# name                 hour_of_day  hour_of_day_sin  hour_of_day_cos
# datetime
# 2023-12-31 23:00:00     0.958333        -0.258819         0.965926
# 2023-12-31 23:15:00     0.958333        -0.258819         0.965926
# 2023-12-31 23:30:00     0.958333        -0.258819         0.965926
# 2023-12-31 23:45:00     0.958333        -0.258819         0.965926
# 2024-01-01 00:00:00     0.000000         0.000000         1.000000
# ...                          ...              ...              ...
# 2024-01-31 21:45:00     0.875000        -0.707107         0.707107
# 2024-01-31 22:00:00     0.916667        -0.500000         0.866025
# 2024-01-31 22:15:00     0.916667        -0.500000         0.866025
# 2024-01-31 22:30:00     0.916667        -0.500000         0.866025
# 2024-01-31 22:45:00     0.916667        -0.500000         0.866025
#
# [2976 rows x 11 columns]

# %%
plt.figure(figsize=(14,4))
sns.boxplot(pivot, x= 'Hour', y= 'Mercado SPOT', palette='RdBu')
plt.title('Hourly Energy Price')
# Out:
# Text(0.5, 1.0, 'Hourly Energy Price')

# %% [markdown]
# # 2. Predictive Modeling

# %% [markdown]
# This first model predicts the energy price every fifteen minutes. Later in the work, I also developed a prediction model to predict energy price on an hourly basis.

# %%
# import libraries for building machine learning model

from sklearn.preprocessing import StandardScaler,MinMaxScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error, root_mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import ColumnTransformer
import joblib

# %% [markdown]
# ## Splitting the data

# %%
# Splitting train and test data
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV, GridSearchCV, check_cv, cross_val_score, TimeSeriesSplit

df_ML = pivot

# Features X, Target y
X = df_ML.drop(['Mercado SPOT'], axis=1)   #features
y = df_ML['Mercado SPOT']   #target
Train_split = 0.2   #20% of the data is allocated for testing.

X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=Train_split, shuffle=False)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=Train_split, shuffle=False)

# %%
# plot training, validation, and testing data
plt.rcParams['figure.figsize'] = [16, 4]
sns.lineplot(x= X_train.index, y=y_train, label = 'Train Data')
sns.lineplot(x=X_val.index, y=y_val, label = 'Validation Data')
sns.lineplot(x=X_test.index, y= y_test, label ='Test Data')
plt.legend(loc='upper right')
plt.title('Train/Test Data Split')
plt.show()

# %% [markdown]
# ## Model Building and Evaluation

# %%
# num of folds and error metrics
num_of_folds = 5
error_metrics= {'neg_mean_squared_error','neg_mean_absolute_error','r2'}
metric_short = {'neg_mean_squared_error','neg_mean_absolute_error','r2'}


# models
models = {
    ('RFR', RandomForestRegressor()),
    ('XGB', XGBRegressor()), 
    ('LR', LinearRegression()),
    ('GBR', GradientBoostingRegressor()),
    ('DTR', DecisionTreeRegressor()),
}

# %%
for scoring in error_metrics:
    results =[] # list of metric results
    msg=[] #list of summary of results
    names =[] #list of name of the models
    print('##### Evaluation metric: ', scoring)

    for name, model in models:
        print(f'\nTraining model: {name} with {scoring}...')
        cross_validation =TimeSeriesSplit(n_splits=num_of_folds)

        #start the cross-validation process and print verbose output
        print(f'Perfroming TimeSeriesSplit with {num_of_folds} folds...')

        cv_results = cross_val_score(model,X_train,y_train,cv=cross_validation,scoring=scoring)

        print(f'Model: {model}, {scoring} Men: {cv_results.mean():.4f}, std:{cv_results.std():.4f}\n')

        results.append(cv_results)
        names.append(name)
        resume = (name,cv_results.mean(), cv_results.std())
        msg.append(resume)

 # Compare results between algorithms
    fig = plt.figure()
    fig.suptitle('Compare metric result for algorithms: %s' %scoring)
    ax = fig.add_subplot(111)
    ax.set_xlabel('Candidate models')
    ax.set_ylabel('%s' %scoring)
    plt.boxplot(results)
    ax.set_xticklabels(names)
    # Show a grid for better readability
    ax.grid(True, axis='y', linestyle='--', alpha=0.7)
    plt.show()

    results = []
# Out:
# ##### Evaluation metric:  neg_mean_absolute_error
#
# Training model: RFR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: RandomForestRegressor(), neg_mean_absolute_error Men: -13.3767, std:4.3126
#
#
# Training model: LR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: LinearRegression(), neg_mean_absolute_error Men: -26.5723, std:26.5883
#
#
# Training model: XGB with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...), neg_mean_absolute_error Men: -13.7753, std:4.1104
#
#
# Training model: DTR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: DecisionTreeRegressor(), neg_mean_absolute_error Men: -14.9292, std:4.4747
#
#
# Training model: GBR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: GradientBoostingRegressor(), neg_mean_absolute_error Men: -13.5992, std:5.1905
# ##### Evaluation metric:  r2
#
# Training model: RFR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: RandomForestRegressor(), r2 Men: 0.3867, std:0.1724
#
#
# Training model: LR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: LinearRegression(), r2 Men: -2.1475, std:5.0055
#
#
# Training model: XGB with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...), r2 Men: 0.3517, std:0.1769
#
#
# Training model: DTR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: DecisionTreeRegressor(), r2 Men: 0.2574, std:0.1386
#
#
# Training model: GBR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: GradientBoostingRegressor(), r2 Men: 0.3825, std:0.2074
# ##### Evaluation metric:  neg_mean_squared_error
#
# Training model: RFR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: RandomForestRegressor(), neg_mean_squared_error Men: -297.6857, std:162.3387
#
#
# Training model: LR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: LinearRegression(), neg_mean_squared_error Men: -1948.7967, std:3378.4863
#
#
# Training model: XGB with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...), neg_mean_squared_error Men: -308.5356, std:160.4464
#
#
# Training model: DTR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: DecisionTreeRegressor(), neg_mean_squared_error Men: -333.6522, std:156.3850
#
#
# Training model: GBR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: GradientBoostingRegressor(), neg_mean_squared_error Men: -311.1889, std:191.6698

# %% [markdown]
# ## Best Model Hyperparameters Adjustment

# %%
model = RandomForestRegressor()
scoring='r2'
params = {
    # Number of trees in random forest
    'n_estimators': [100, 500],  # default=100
    'max_depth': [2, None],  #deafult = None
}


# Search for the best combination of hyperparameters
cross_validation = TimeSeriesSplit(n_splits=5)
my_cv = cross_validation.split(X_val)
gsearch = GridSearchCV(estimator=model, param_grid=params, scoring=scoring, cv=my_cv, verbose=3)
gsearch.fit(X_val, y_val)

# Print best Result
print("Best result: %f using the following hyperparameters %s" % (gsearch.best_score_, gsearch.best_params_))
means = gsearch.cv_results_['mean_test_score']
stds = gsearch.cv_results_['std_test_score']
params = gsearch.cv_results_['params']
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .....max_depth=2, n_estimators=100;, score=0.522 total time=   0.0s
# [CV 2/5] END .....max_depth=2, n_estimators=100;, score=0.581 total time=   0.0s
# [CV 3/5] END .....max_depth=2, n_estimators=100;, score=0.262 total time=   0.0s
# [CV 4/5] END .....max_depth=2, n_estimators=100;, score=0.453 total time=   0.0s
# [CV 5/5] END .....max_depth=2, n_estimators=100;, score=0.467 total time=   0.0s
# [CV 1/5] END .....max_depth=2, n_estimators=500;, score=0.512 total time=   0.1s
# [CV 2/5] END .....max_depth=2, n_estimators=500;, score=0.587 total time=   0.2s
# [CV 3/5] END .....max_depth=2, n_estimators=500;, score=0.274 total time=   0.2s
# [CV 4/5] END .....max_depth=2, n_estimators=500;, score=0.417 total time=   0.2s
# [CV 5/5] END .....max_depth=2, n_estimators=500;, score=0.469 total time=   0.2s
# [CV 1/5] END ..max_depth=None, n_estimators=100;, score=0.482 total time=   0.0s
# [CV 2/5] END ..max_depth=None, n_estimators=100;, score=0.585 total time=   0.0s
# [CV 3/5] END ..max_depth=None, n_estimators=100;, score=0.444 total time=   0.0s
# [CV 4/5] END ..max_depth=None, n_estimators=100;, score=0.745 total time=   0.0s
# [CV 5/5] END ..max_depth=None, n_estimators=100;, score=0.713 total time=   0.0s
# [CV 1/5] END ..max_depth=None, n_estimators=500;, score=0.479 total time=   0.2s
# [CV 2/5] END ..max_depth=None, n_estimators=500;, score=0.574 total time=   0.2s
# [CV 3/5] END ..max_depth=None, n_estimators=500;, score=0.449 total time=   0.3s
# [CV 4/5] END ..max_depth=None, n_estimators=500;, score=0.734 total time=   0.4s
# [CV 5/5] END ..max_depth=None, n_estimators=500;, score=0.690 total time=   0.5s
# Best result: 0.593709 using the following hyperparameters {'max_depth': None, 'n_estimators': 100}

# %% [markdown]
# ## Final Evaluation of the Model

# %%
# make prediction on the test dataset 
final_model_v1 = RandomForestRegressor(n_estimators=100, max_depth=None) # Model with the optimal parameters
final_model_v1.fit(X_train, y_train)
y_predict_v1 = final_model_v1.predict(X_test) # Making prediction

# %% [markdown]
# Evaluation Metrics for this final model (MAE, RMSE)

# %%
# Calculating MAE
MAE_minute_1 = mean_absolute_error(y_test, y_predict_v1)

# Calculating RMSE
MSE = mean_squared_error(y_test, y_predict_v1)
RMSE_minute_1 = np.sqrt(MSE)

print('Evaluation Metrics Results.....')
print('MAE: ', MAE_minute_1)
print('RMSE: ', RMSE_minute_1)
# Out:
# Evaluation Metrics Results.....
# MAE:  20.76056224832217
# RMSE:  22.681800145967877

# %% [markdown]
# Feature Importance

# %% [markdown]
# The following plot shows how much each input variable (feature) contributes to the model’s predictions. In other words, it indicates which features the model relies on the most when making decisions.

# %%
importances = final_model_v1.feature_importances_    #retrieve the feature importance score
features = X.columns  #the columns names

sns.barplot(x=importances, y=features, palette='RdBu')
plt.show()

# %% [markdown]
# In this prediction model, the hydropower generation feature tends to have a significant impact.

# %% [markdown]
# ## Plot the Predictions Vs the Real Values

# %%
def  prediction_plot (y_test_data, y_predict_data):
    import plotly.graph_objects as go
    fig = go.Figure()

    # plotting the actual spot market energy price
    fig.add_trace(go.Scatter(
        x=y_test_data.index, y=y_test_data, mode = 'lines',
        name='True values', line = dict(color='blue', width=1.5)
    ))

    # plotting the predicted spot market energy price
    fig.add_trace(go.Scatter(
        x=y_test_data.index, y=y_predict_data, mode ='lines',
        name='Predicted values', line = dict(color='red', width=1.5, dash='dot')
    ))

    # Update layout for a more beautiful plot
    fig.update_layout(
        title='True vs Predicted Spot Market Energy Price',
        xaxis_title='Date/Time',
        yaxis_title='Energy Price (Euro/MWh)',
        template='plotly',  # dark theme, can change to 'plotly' for light theme
        hovermode='x unified',  # hover over to show values for both lines at a time
        legend=dict(
            x=0.01, y=0.99,  # position of legend
            traceorder='normal',
            font=dict(family="Arial", size=12, color="white"),
            bgcolor='rgba(0, 0, 0, 0.3)',
            bordercolor='white',
            borderwidth=1
        ),
    
    
    )

    # Show the plot
    fig.show()

# %%
prediction_plot(y_test, y_predict_v1)

# %% [markdown]
# Pipeline

# %%
make_pipeline(final_model_v1)
# Out:
# Pipeline(steps=[('randomforestregressor', RandomForestRegressor())])

# %%
joblib.dump(final_model_v1,'Energy_price_prediction_v1')
# Out:
# ['Energy_price_prediction_v1']

# %% [markdown]
# ## Hourly Prediction

# %% [markdown]
# In the prediction model above, the data were sampled every 15 minutes. Therefore, the predictions are made at 15-minute intervals. However, we are now repeating the same prediction using data in an hourly format to develop a model that predicts the hourly energy price.

# %%
Hourly_pivot.index = pd.to_datetime(Hourly_pivot.index)

# %% [markdown]
# The Energy Spot Market price is already provided on an hourly basis, but the energy-generation data from different sources is not. To convert these data into an hourly format, I resampled the DataFrame so that each hour contains the average value of the four fifteen-minute intervals.

# %%
Hourly_pivot= Hourly_pivot.resample('H').mean()

# %%
Hourly_pivot
# Out:
# name                 Hidráulica UGH  Mercado SPOT  Nuclear  Previsión diaria  \
# datetime
# 2023-12-31 23:00:00       631.65625         63.33   1779.3          21854.50
# 2024-01-01 00:00:00       637.81250         50.09   1779.3          21981.25
# 2024-01-01 01:00:00       529.62500         47.50   1779.3          20403.00
# 2024-01-01 02:00:00       469.40000         43.50   1779.3          18777.00
# 2024-01-01 03:00:00       418.78750         42.50   1779.3          18150.50
# ...                             ...           ...      ...               ...
# 2024-01-31 18:00:00      2033.02500        119.47   1779.3          33612.50
# 2024-01-31 19:00:00      2044.30625           NaN   1779.3          34230.75
# 2024-01-31 20:00:00      1980.90000         94.54   1779.3          33363.00
# 2024-01-31 21:00:00      1827.70000         85.00   1779.3          30290.00
# 2024-01-31 22:00:00      1545.18125         77.52   1779.3          27283.50
#
# name                 Previsión eólica  Solar fotovoltaica
# datetime
# 2023-12-31 23:00:00           5184.50                 0.0
# 2024-01-01 00:00:00           5243.25                 0.0
# 2024-01-01 01:00:00           5323.50                 0.0
# 2024-01-01 02:00:00           5343.75                 0.0
# 2024-01-01 03:00:00           5156.25                 0.0
# ...                               ...                 ...
# 2024-01-31 18:00:00           2794.25                 0.0
# 2024-01-31 19:00:00           3215.00                 0.0
# 2024-01-31 20:00:00           3573.00                 0.0
# 2024-01-31 21:00:00           3946.75                 0.0
# 2024-01-31 22:00:00           4116.00                 0.0
#
# [744 rows x 6 columns]

# %%
Hourly_pivot.isna().sum()
# Out:
# name
# Hidráulica UGH         0
# Mercado SPOT          35
# Nuclear                0
# Previsión diaria       0
# Previsión eólica       0
# Solar fotovoltaica    26
# dtype: int64

# %% [markdown]
# **Missing Values**: The missing values were replaced using the forward fill method, assuming that the energy price in the next hour will be the same as the current price.

# %%
Hourly_pivot['Mercado SPOT'].ffill(inplace=True)
Hourly_pivot['Solar fotovoltaica'].ffill(inplace=True)
# Export to Excel
Hourly_pivot.to_excel('Hourly_pivot.xlsx')
Hourly_pivot
# Out:
# name                 Hidráulica UGH  Mercado SPOT  Nuclear  Previsión diaria  \
# datetime
# 2023-12-31 23:00:00       631.65625         63.33   1779.3          21854.50
# 2024-01-01 00:00:00       637.81250         50.09   1779.3          21981.25
# 2024-01-01 01:00:00       529.62500         47.50   1779.3          20403.00
# 2024-01-01 02:00:00       469.40000         43.50   1779.3          18777.00
# 2024-01-01 03:00:00       418.78750         42.50   1779.3          18150.50
# ...                             ...           ...      ...               ...
# 2024-01-31 18:00:00      2033.02500        119.47   1779.3          33612.50
# 2024-01-31 19:00:00      2044.30625        119.47   1779.3          34230.75
# 2024-01-31 20:00:00      1980.90000         94.54   1779.3          33363.00
# 2024-01-31 21:00:00      1827.70000         85.00   1779.3          30290.00
# 2024-01-31 22:00:00      1545.18125         77.52   1779.3          27283.50
#
# name                 Previsión eólica  Solar fotovoltaica
# datetime
# 2023-12-31 23:00:00           5184.50                 0.0
# 2024-01-01 00:00:00           5243.25                 0.0
# 2024-01-01 01:00:00           5323.50                 0.0
# 2024-01-01 02:00:00           5343.75                 0.0
# 2024-01-01 03:00:00           5156.25                 0.0
# ...                               ...                 ...
# 2024-01-31 18:00:00           2794.25                 0.0
# 2024-01-31 19:00:00           3215.00                 0.0
# 2024-01-31 20:00:00           3573.00                 0.0
# 2024-01-31 21:00:00           3946.75                 0.0
# 2024-01-31 22:00:00           4116.00                 0.0
#
# [744 rows x 6 columns]

# %%
#temporal features
#calling the function to create temporal features
Hourly_pivot = temporal_features(Hourly_pivot)

# %% [markdown]
# ## Splitting Data

# %%
# Splitting train and test dataset
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV, GridSearchCV, check_cv, cross_val_score, TimeSeriesSplit
df_ML_hourly = Hourly_pivot

# Features X, Target y
X = df_ML_hourly.drop(['Mercado SPOT'], axis=1)   #features
y = df_ML_hourly['Mercado SPOT']   #target
Train_split = 0.2   #20% of the data is allocated for testing.

X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=Train_split, shuffle=False)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=Train_split, shuffle=False)

# %% [markdown]
# ## Model Building and Evaluation

# %%
# num of folds and error metrics
num_of_folds = 5
error_metrics= {'neg_mean_squared_error','neg_mean_absolute_error','r2'}
metric_short = {'neg_mean_squared_error','neg_mean_absolute_error','r2'}


# models
models = {
    ('RFR', RandomForestRegressor()),
    ('XGB', XGBRegressor()), 
    ('LR', LinearRegression()),
    ('GBR', GradientBoostingRegressor()),
    ('DTR', DecisionTreeRegressor()),
}

for scoring in error_metrics:
    results =[] # list of metric results
    msg=[] #list of summary of results
    names =[] #list of name of the models
    print('##### Evaluation metric: ', scoring)

    for name, model in models:
        print(f'\nTraining model: {name} with {scoring}...')
        cross_validation =TimeSeriesSplit(n_splits=num_of_folds)

        #start the cross-validation process and print verbose output
        print(f'Perfroming TimeSeriesSplit with {num_of_folds} folds...')

        cv_results = cross_val_score(model,X_train,y_train,cv=cross_validation,scoring=scoring)

        print(f'Model: {model}, {scoring} Men: {cv_results.mean():.4f}, std:{cv_results.std():.4f}\n')

        results.append(cv_results)
        names.append(name)
        resume = (name,cv_results.mean(), cv_results.std())
        msg.append(resume)

 # Compare results between algorithms
    fig = plt.figure()
    fig.suptitle('Compare metric result for algorithms: %s' %scoring)
    ax = fig.add_subplot(111)
    ax.set_xlabel('Candidate models')
    ax.set_ylabel('%s' %scoring)
    plt.boxplot(results)
    ax.set_xticklabels(names)
    # Show a grid for better readability
    ax.grid(True, axis='y', linestyle='--', alpha=0.7)
    plt.show()

    results = []
# Out:
# ##### Evaluation metric:  neg_mean_absolute_error
#
# Training model: LR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: LinearRegression(), neg_mean_absolute_error Men: -27.5410, std:28.6272
#
#
# Training model: DTR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: DecisionTreeRegressor(), neg_mean_absolute_error Men: -14.4445, std:5.3543
#
#
# Training model: XGB with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...), neg_mean_absolute_error Men: -13.2604, std:4.5841
#
#
# Training model: RFR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: RandomForestRegressor(), neg_mean_absolute_error Men: -12.6820, std:5.2103
#
#
# Training model: GBR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: GradientBoostingRegressor(), neg_mean_absolute_error Men: -13.2023, std:4.9404
# ##### Evaluation metric:  r2
#
# Training model: LR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: LinearRegression(), r2 Men: -2.4659, std:5.6114
#
#
# Training model: DTR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: DecisionTreeRegressor(), r2 Men: 0.2341, std:0.2578
#
#
# Training model: XGB with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...), r2 Men: 0.3628, std:0.2335
#
#
# Training model: RFR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: RandomForestRegressor(), r2 Men: 0.4154, std:0.2252
#
#
# Training model: GBR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: GradientBoostingRegressor(), r2 Men: 0.3797, std:0.2174
# ##### Evaluation metric:  neg_mean_squared_error
#
# Training model: LR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: LinearRegression(), neg_mean_squared_error Men: -2187.0683, std:3857.9351
#
#
# Training model: DTR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: DecisionTreeRegressor(), neg_mean_squared_error Men: -405.5270, std:289.7590
#
#
# Training model: XGB with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...), neg_mean_squared_error Men: -301.4746, std:167.3704
#
#
# Training model: RFR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: RandomForestRegressor(), neg_mean_squared_error Men: -286.5712, std:175.1882
#
#
# Training model: GBR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: GradientBoostingRegressor(), neg_mean_squared_error Men: -304.3135, std:188.8427

# %% [markdown]
# Best Model Hyperparameters Adjustment

# %%
model = RandomForestRegressor()
scoring='r2'
params = {
    # Number of trees in random forest
    'n_estimators': [100, 500],  # default=100
    'max_depth': [2, None],  #deafult = None
}


# Search for the best combination of hyperparameters
cross_validation = TimeSeriesSplit(n_splits=5)
my_cv = cross_validation.split(X_val)
gsearch = GridSearchCV(estimator=model, param_grid=params, scoring=scoring, cv=my_cv, verbose=3)
gsearch.fit(X_val, y_val)

# Print best Result
print("Best result: %f using the following hyperparameters %s" % (gsearch.best_score_, gsearch.best_params_))
means = gsearch.cv_results_['mean_test_score']
stds = gsearch.cv_results_['std_test_score']
params = gsearch.cv_results_['params']
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .....max_depth=2, n_estimators=100;, score=0.472 total time=   0.0s
# [CV 2/5] END .....max_depth=2, n_estimators=100;, score=0.628 total time=   0.0s
# [CV 3/5] END .....max_depth=2, n_estimators=100;, score=0.136 total time=   0.0s
# [CV 4/5] END .....max_depth=2, n_estimators=100;, score=0.652 total time=   0.0s
# [CV 5/5] END .....max_depth=2, n_estimators=100;, score=0.617 total time=   0.0s
# [CV 1/5] END .....max_depth=2, n_estimators=500;, score=0.444 total time=   0.1s
# [CV 2/5] END .....max_depth=2, n_estimators=500;, score=0.625 total time=   0.1s
# [CV 3/5] END .....max_depth=2, n_estimators=500;, score=0.191 total time=   0.1s
# [CV 4/5] END .....max_depth=2, n_estimators=500;, score=0.657 total time=   0.1s
# [CV 5/5] END .....max_depth=2, n_estimators=500;, score=0.617 total time=   0.2s
# [CV 1/5] END ..max_depth=None, n_estimators=100;, score=0.445 total time=   0.0s
# [CV 2/5] END ..max_depth=None, n_estimators=100;, score=0.658 total time=   0.0s
# [CV 3/5] END ..max_depth=None, n_estimators=100;, score=0.213 total time=   0.0s
# [CV 4/5] END ..max_depth=None, n_estimators=100;, score=0.684 total time=   0.0s
# [CV 5/5] END ..max_depth=None, n_estimators=100;, score=0.617 total time=   0.0s
# [CV 1/5] END ..max_depth=None, n_estimators=500;, score=0.442 total time=   0.2s
# [CV 2/5] END ..max_depth=None, n_estimators=500;, score=0.641 total time=   0.2s
# [CV 3/5] END ..max_depth=None, n_estimators=500;, score=0.194 total time=   0.2s
# [CV 4/5] END ..max_depth=None, n_estimators=500;, score=0.699 total time=   0.2s
# [CV 5/5] END ..max_depth=None, n_estimators=500;, score=0.604 total time=   0.2s
# Best result: 0.523377 using the following hyperparameters {'max_depth': None, 'n_estimators': 100}

# %% [markdown]
# ## Final Evaluation of the Model

# %%
# make prediction on the test dataset
final_model_Hourly_v1 = RandomForestRegressor(n_estimators=500, max_depth=None) # Model with the optimal parameters
final_model_Hourly_v1.fit(X_train, y_train)
y_predict_Hourly_v1 = final_model_Hourly_v1.predict(X_test) # Making prediction

# %%
# Calculating MAE
MAE_hourly_1 = mean_absolute_error(y_test, y_predict_Hourly_v1)

# Calculating RMSE
MSE = mean_squared_error(y_test, y_predict_Hourly_v1)
RMSE_hourly_1 = np.sqrt(MSE)

print('Evaluation Metrics Results.....')
print('MAE: ', MAE_hourly_1)
print('RMSE: ', RMSE_hourly_1)
# Out:
# Evaluation Metrics Results.....
# MAE:  19.929496241610714
# RMSE:  21.608653963852326

# %%
#feature importance in the prediction model
importances = final_model_Hourly_v1.feature_importances_
features = final_model_Hourly_v1.feature_names_in_

sns.barplot(x=importances, y=features, palette='RdBu')
plt.title('Features Importance')
plt.show()

# %% [markdown]
# ## Plot the Predictions Vs the Real Values

# %%
prediction_plot(y_test, y_predict_Hourly_v1)

# %% [markdown]
# ## Hourly and Minute Energy Price Prediction MAE and RMSE Scoes

# %%
pd.set_option('display.max_colwidth', 100) 
MAE_RMSE_Scores = pd.DataFrame({'MAE':[MAE_minute_1,MAE_hourly_1], 'RMSE':[RMSE_minute_1,RMSE_hourly_1]}, index=['Energy Price Quaterly Prediction', 'Energy Price Hourly Prediction'])
MAE_RMSE_Scores
# Out:
#                                         MAE       RMSE
# Energy Price Quaterly Prediction  20.760562  22.681800
# Energy Price Hourly Prediction    19.929496  21.608654

# %% [markdown]
# Although both the quarterly prediction and the hourly prediction use the same features, their MAE and RMSE scores differ. These discrepancies may be due to the difference in sample size. The quarterly prediction has a larger sample size compared to the hourly prediction, which can lead to greater error between the test data and the predicted values.

# %% [markdown]
# # Predictive Modeling 2

# %% [markdown]
# Here, we are creating new features to improve the model. One type of feature we can add is lag variables. This prediction model uses a dataset with data recorded every fifteen minutes. To create an hourly energy prediction model, the dataset would need to be resampled to an hourly format. However, for now, we are developing a model using the 15-minute interval data with the added lagged variable features.

# %%
pivot['Lag_1_day'] = pivot['Mercado SPOT'].shift(96) #Lag of 24 hours (1 day)
pivot['Lag_2_days'] = pivot['Mercado SPOT'].shift(192) #Lag of 48 horurs (2 day)

# %%
pivot
# Out:
# name                 Hidráulica UGH  Mercado SPOT  Nuclear  Previsión diaria  \
# datetime
# 2023-12-31 23:00:00         626.950         63.33   1779.3           21981.0
# 2023-12-31 23:15:00         647.975         63.33   1779.3           21863.0
# 2023-12-31 23:30:00         625.850         63.33   1779.3           21807.0
# 2023-12-31 23:45:00         625.850         63.33   1779.3           21767.0
# 2024-01-01 00:00:00         663.125         50.09   1779.3           22640.0
# ...                             ...           ...      ...               ...
# 2024-01-31 21:45:00        1673.050         85.00   1779.3           29007.0
# 2024-01-31 22:00:00        1588.950         77.52   1779.3           28070.0
# 2024-01-31 22:15:00        1547.425         77.52   1779.3           27495.0
# 2024-01-31 22:30:00        1547.425         77.52   1779.3           27003.0
# 2024-01-31 22:45:00        1496.925         77.52   1779.3           26566.0
#
# name                 Previsión eólica  Solar fotovoltaica  Hour  Month  \
# datetime
# 2023-12-31 23:00:00            5218.0                 0.0    23     12
# 2023-12-31 23:15:00            5198.0                 0.0    23     12
# 2023-12-31 23:30:00            5175.0                 0.0    23     12
# 2023-12-31 23:45:00            5147.0                 0.0    23     12
# 2024-01-01 00:00:00            5299.0                 0.0     0      1
# ...                               ...                 ...   ...    ...
# 2024-01-31 21:45:00            4059.0                 0.0    21      1
# 2024-01-31 22:00:00            4027.0                 0.0    22      1
# 2024-01-31 22:15:00            4090.0                 0.0    22      1
# 2024-01-31 22:30:00            4148.0                 0.0    22      1
# 2024-01-31 22:45:00            4199.0                 0.0    22      1
#
# name                 hour_of_day  hour_of_day_sin  hour_of_day_cos  Lag_1_day  \
# datetime
# 2023-12-31 23:00:00     0.958333        -0.258819         0.965926        NaN
# 2023-12-31 23:15:00     0.958333        -0.258819         0.965926        NaN
# 2023-12-31 23:30:00     0.958333        -0.258819         0.965926        NaN
# 2023-12-31 23:45:00     0.958333        -0.258819         0.965926        NaN
# 2024-01-01 00:00:00     0.000000         0.000000         1.000000        NaN
# ...                          ...              ...              ...        ...
# 2024-01-31 21:45:00     0.875000        -0.707107         0.707107      88.70
# 2024-01-31 22:00:00     0.916667        -0.500000         0.866025      78.78
# 2024-01-31 22:15:00     0.916667        -0.500000         0.866025      78.78
# 2024-01-31 22:30:00     0.916667        -0.500000         0.866025      78.78
# 2024-01-31 22:45:00     0.916667        -0.500000         0.866025      78.78
#
# name                 Lag_2_days
# datetime
# 2023-12-31 23:00:00         NaN
# 2023-12-31 23:15:00         NaN
# 2023-12-31 23:30:00         NaN
# 2023-12-31 23:45:00         NaN
# 2024-01-01 00:00:00         NaN
# ...                         ...
# 2024-01-31 21:45:00       87.00
# 2024-01-31 22:00:00       80.29
# 2024-01-31 22:15:00       80.29
# 2024-01-31 22:30:00       80.29
# 2024-01-31 22:45:00       80.29
#
# [2976 rows x 13 columns]

# %% [markdown]
# ## Correlation

# %%
# Calculate the correlation matrix
corr = pivot.iloc[:,:].corr(method='pearson') 

# Plot Heat Map,
f, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(corr, annot=True, fmt=".2f" )
plt.title('Correlation')
plt.show()

# %% [markdown]
# ## Splitting the Data

# %%
# Splitting train and test data
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV, GridSearchCV, check_cv, cross_val_score, TimeSeriesSplit

df_ML_2 = pivot
df_ML_2.dropna(inplace=True)

# Features X, Target y
X = df_ML_2.drop(['Mercado SPOT'], axis=1)
y = df_ML_2['Mercado SPOT']
Train_split = 0.2

X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=Train_split, shuffle=False)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=Train_split, shuffle=False)

# %% [markdown]
# Scaling the Data

# %% [markdown]
# The model performs worse when the data are scaled, so I decided to remove scaling. Distance-based models, like linear regression, usually benefit from scaling, but tree-based models, such as Random Forest, XGBoost, and Decision Tree, often perform worse. Scaling can alter the original feature distribution.

# %%
'''scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)'''
# Out:
# 'scaler = StandardScaler()\nX_train_scaled = scaler.fit_transform(X_train)\nX_val_scaled = scaler.transform(X_val)\nX_test_scaled = scaler.transform(X_test)'

# %% [markdown]
# ## Model Building and Evaluation

# %%
# num of folds and error metrics
num_of_folds = 5
error_metrics= {'neg_mean_squared_error','neg_mean_absolute_error','r2'}
metric_short = {'neg_mean_squared_error','neg_mean_absolute_error','r2'}


# models
models = {
    ('RFR', RandomForestRegressor()),
    ('XGB', XGBRegressor()), 
    ('LR', LinearRegression()),
    ('GBR', GradientBoostingRegressor()),
    ('DTR', DecisionTreeRegressor()),
}

# %%
for scoring in error_metrics:
    results =[] # list of metric results
    msg=[] #list of summary of results
    names =[] #list of name of the models
    print('##### Evaluation metric: ', scoring)

    for name, model in models:
        print(f'\nTraining model: {name} with {scoring}...')
        cross_validation =TimeSeriesSplit(n_splits=num_of_folds)

        #start the cross-validation process and print verbose output
        print(f'Perfroming TimeSeriesSplit with {num_of_folds} folds...')

        cv_results = cross_val_score(model,X_train,y_train,cv=cross_validation,scoring=scoring)

        print(f'Model: {model}, {scoring} Men: {cv_results.mean():.4f}, std:{cv_results.std():.4f}\n')

        results.append(cv_results)
        names.append(name)
        resume = (name,cv_results.mean(), cv_results.std())
        msg.append(resume)

 # Compare results between algorithms
    fig = plt.figure()
    fig.suptitle('Compare metric result for algorithms: %s' %scoring)
    ax = fig.add_subplot(111)
    ax.set_xlabel('Candidate models')
    ax.set_ylabel('%s' %scoring)
    plt.boxplot(results)
    ax.set_xticklabels(names)
    # Show a grid for better readability
    ax.grid(True, axis='y', linestyle='--', alpha=0.7)
    plt.show()

    results = []
# Out:
# ##### Evaluation metric:  neg_mean_absolute_error
#
# Training model: RFR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: RandomForestRegressor(), neg_mean_absolute_error Men: -14.9407, std:5.4092
#
#
# Training model: XGB with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...), neg_mean_absolute_error Men: -14.6687, std:5.4617
#
#
# Training model: DTR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: DecisionTreeRegressor(), neg_mean_absolute_error Men: -16.0490, std:5.5929
#
#
# Training model: GBR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: GradientBoostingRegressor(), neg_mean_absolute_error Men: -15.0960, std:5.5956
#
#
# Training model: LR with neg_mean_absolute_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: LinearRegression(), neg_mean_absolute_error Men: -41.7273, std:54.4011
# ##### Evaluation metric:  r2
#
# Training model: RFR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: RandomForestRegressor(), r2 Men: 0.1906, std:0.4173
#
#
# Training model: XGB with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...), r2 Men: 0.2367, std:0.4002
#
#
# Training model: DTR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: DecisionTreeRegressor(), r2 Men: -0.0231, std:0.5395
#
#
# Training model: GBR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: GradientBoostingRegressor(), r2 Men: 0.2358, std:0.3357
#
#
# Training model: LR with r2...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: LinearRegression(), r2 Men: -61.5459, std:124.0181
# ##### Evaluation metric:  neg_mean_squared_error
#
# Training model: RFR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: RandomForestRegressor(), neg_mean_squared_error Men: -392.8610, std:265.5188
#
#
# Training model: XGB with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...), neg_mean_squared_error Men: -376.3738, std:270.9869
#
#
# Training model: DTR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: DecisionTreeRegressor(), neg_mean_squared_error Men: -470.2819, std:345.0851
#
#
# Training model: GBR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: GradientBoostingRegressor(), neg_mean_squared_error Men: -391.8647, std:303.1416
#
#
# Training model: LR with neg_mean_squared_error...
# Perfroming TimeSeriesSplit with 5 folds...
# Model: LinearRegression(), neg_mean_squared_error Men: -13672.5966, std:26684.2147

# %% [markdown]
# ## Best Model Hyper Parameters Adjustment

# %%
model = LinearRegression()
scoring='r2'
params = {'copy_X': [True,False], 
               'fit_intercept': [True,False], 
               'n_jobs': [1,5,10,15,None], 
               'positive': [True,False]}
   


# Search for the best combination of hyperparameters
cross_validation = TimeSeriesSplit(n_splits=5)
my_cv = cross_validation.split(X_val)
gsearch = GridSearchCV(estimator=model, param_grid=params, scoring=scoring, cv=my_cv, verbose=3)
gsearch.fit(X_val, y_val)

# Print best Result
print("Best result: %f using the following hyperparameters %s" % (gsearch.best_score_, gsearch.best_params_))
means = gsearch.cv_results_['mean_test_score']
stds = gsearch.cv_results_['std_test_score']
params = gsearch.cv_results_['params']
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=1, positive=True;, score=0.581 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=1, positive=True;, score=0.810 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=1, positive=True;, score=-0.633 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=1, positive=True;, score=0.467 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=1, positive=True;, score=0.796 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=1, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=1, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=1, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=1, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=1, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=5, positive=True;, score=0.581 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=5, positive=True;, score=0.810 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=5, positive=True;, score=-0.633 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=5, positive=True;, score=0.467 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=5, positive=True;, score=0.796 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=5, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=5, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=5, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=5, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=5, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=10, positive=True;, score=0.581 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=10, positive=True;, score=0.810 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=10, positive=True;, score=-0.633 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=10, positive=True;, score=0.467 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=10, positive=True;, score=0.796 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=10, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=10, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=10, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=10, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=10, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=15, positive=True;, score=0.581 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=15, positive=True;, score=0.810 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=15, positive=True;, score=-0.633 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=15, positive=True;, score=0.467 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=15, positive=True;, score=0.796 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=15, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=15, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=15, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=15, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=15, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=0.581 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=0.810 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=-0.633 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=0.467 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=True;, score=0.796 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=True, n_jobs=None, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=1, positive=True;, score=0.402 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=1, positive=True;, score=0.643 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=1, positive=True;, score=0.315 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=1, positive=True;, score=0.600 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=1, positive=True;, score=0.718 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=1, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=1, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=1, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=1, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=1, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=5, positive=True;, score=0.402 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=5, positive=True;, score=0.643 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=5, positive=True;, score=0.315 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=5, positive=True;, score=0.600 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=5, positive=True;, score=0.718 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=5, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=5, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=5, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=5, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=5, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=10, positive=True;, score=0.402 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=10, positive=True;, score=0.643 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=10, positive=True;, score=0.315 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=10, positive=True;, score=0.600 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=10, positive=True;, score=0.718 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=10, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=10, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=10, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=10, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=10, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=15, positive=True;, score=0.402 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=15, positive=True;, score=0.643 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=15, positive=True;, score=0.315 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=15, positive=True;, score=0.600 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=15, positive=True;, score=0.718 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=15, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=15, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=15, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=15, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=15, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=0.402 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=0.643 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=0.315 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=0.600 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=True;, score=0.718 total time=   0.0s
# [CV 1/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=True, fit_intercept=False, n_jobs=None, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=1, positive=True;, score=0.581 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=1, positive=True;, score=0.810 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=1, positive=True;, score=-0.633 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=1, positive=True;, score=0.467 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=1, positive=True;, score=0.796 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=1, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=1, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=1, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=1, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=1, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=5, positive=True;, score=0.581 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=5, positive=True;, score=0.810 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=5, positive=True;, score=-0.633 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=5, positive=True;, score=0.467 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=5, positive=True;, score=0.796 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=5, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=5, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=5, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=5, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=5, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=10, positive=True;, score=0.581 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=10, positive=True;, score=0.810 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=10, positive=True;, score=-0.633 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=10, positive=True;, score=0.467 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=10, positive=True;, score=0.796 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=10, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=10, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=10, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=10, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=10, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=15, positive=True;, score=0.581 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=15, positive=True;, score=0.810 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=15, positive=True;, score=-0.633 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=15, positive=True;, score=0.467 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=15, positive=True;, score=0.796 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=15, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=15, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=15, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=15, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=15, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=0.581 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=0.810 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=-0.633 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=0.467 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=True;, score=0.796 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=True, n_jobs=None, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=1, positive=True;, score=0.402 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=1, positive=True;, score=0.643 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=1, positive=True;, score=0.315 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=1, positive=True;, score=0.600 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=1, positive=True;, score=0.718 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=1, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=1, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=1, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=1, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=1, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=5, positive=True;, score=0.402 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=5, positive=True;, score=0.643 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=5, positive=True;, score=0.315 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=5, positive=True;, score=0.600 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=5, positive=True;, score=0.718 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=5, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=5, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=5, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=5, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=5, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=10, positive=True;, score=0.402 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=10, positive=True;, score=0.643 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=10, positive=True;, score=0.315 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=10, positive=True;, score=0.600 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=10, positive=True;, score=0.718 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=10, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=10, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=10, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=10, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=10, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=15, positive=True;, score=0.402 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=15, positive=True;, score=0.643 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=15, positive=True;, score=0.315 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=15, positive=True;, score=0.600 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=15, positive=True;, score=0.718 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=15, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=15, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=15, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=15, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=15, positive=False;, score=0.743 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=0.402 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=0.643 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=0.315 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=0.600 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=True;, score=0.718 total time=   0.0s
# [CV 1/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-0.160 total time=   0.0s
# [CV 2/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=0.787 total time=   0.0s
# [CV 3/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=-0.014 total time=   0.0s
# [CV 4/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=0.698 total time=   0.0s
# [CV 5/5] END copy_X=False, fit_intercept=False, n_jobs=None, positive=False;, score=0.743 total time=   0.0s
# Best result: 0.535614 using the following hyperparameters {'copy_X': True, 'fit_intercept': False, 'n_jobs': 1, 'positive': True}

# %% [markdown]
# ## Final Evaluation of the Model

# %%
# predict the test dataset
final_model_v2 = LinearRegression(copy_X= True, fit_intercept= False, n_jobs= 1, positive= False) # Model with the optimal parameters
final_model_v2.fit(X_train, y_train)
y_predict_v2 = final_model_v2.predict(X_test) # Making prediction

# %% [markdown]
# Evaluation Metrics for this final model (MAE, RMSE)

# %%
# Calculating MAE
MAE_minute_2 = mean_absolute_error(y_test, y_predict_v2)

# Calculating RMSE
MSE = mean_squared_error(y_test, y_predict_v2)
RMSE_minute_2 = np.sqrt(MSE)

print('Evaluation Metrics Results.....')
print('MAE: ', MAE_minute_2)
print('RMSE: ', RMSE_minute_2)
# Out:
# Evaluation Metrics Results.....
# MAE:  16.30368560270632
# RMSE:  18.103915282786293

# %% [markdown]
# ## Plot prediction

# %%
prediction_plot(y_test, y_predict_v2)

# %% [markdown]
# ## XGB

# %%
model = XGBRegressor()
scoring='r2'
params = {
    # Number of trees in random forest
    'n_estimators': [100, 500],  # default=100
    'max_depth': [2, None],  #deafult = None
}
   


# Search for the best combination of hyperparameters
cross_validation = TimeSeriesSplit(n_splits=5)
my_cv = cross_validation.split(X_val)
gsearch = GridSearchCV(estimator=model, param_grid=params, scoring=scoring, cv=my_cv, verbose=3)
gsearch.fit(X_val, y_val)

# Print best Result
print("Best result: %f using the following hyperparameters %s" % (gsearch.best_score_, gsearch.best_params_))
means = gsearch.cv_results_['mean_test_score']
stds = gsearch.cv_results_['std_test_score']
params = gsearch.cv_results_['params']
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .....max_depth=2, n_estimators=100;, score=0.715 total time=   0.0s
# [CV 2/5] END .....max_depth=2, n_estimators=100;, score=0.524 total time=   0.0s
# [CV 3/5] END .....max_depth=2, n_estimators=100;, score=0.058 total time=   0.0s
# [CV 4/5] END .....max_depth=2, n_estimators=100;, score=0.633 total time=   0.0s
# [CV 5/5] END .....max_depth=2, n_estimators=100;, score=0.579 total time=   0.0s
# [CV 1/5] END .....max_depth=2, n_estimators=500;, score=0.716 total time=   0.0s
# [CV 2/5] END .....max_depth=2, n_estimators=500;, score=0.478 total time=   0.0s
# [CV 3/5] END .....max_depth=2, n_estimators=500;, score=0.038 total time=   0.0s
# [CV 4/5] END .....max_depth=2, n_estimators=500;, score=0.605 total time=   0.0s
# [CV 5/5] END .....max_depth=2, n_estimators=500;, score=0.567 total time=   0.0s
# [CV 1/5] END ..max_depth=None, n_estimators=100;, score=0.515 total time=   0.0s
# [CV 2/5] END ..max_depth=None, n_estimators=100;, score=0.429 total time=   0.0s
# [CV 3/5] END .max_depth=None, n_estimators=100;, score=-0.372 total time=   0.0s
# [CV 4/5] END ..max_depth=None, n_estimators=100;, score=0.539 total time=   0.0s
# [CV 5/5] END ..max_depth=None, n_estimators=100;, score=0.622 total time=   0.0s
# [CV 1/5] END ..max_depth=None, n_estimators=500;, score=0.515 total time=   0.0s
# [CV 2/5] END ..max_depth=None, n_estimators=500;, score=0.429 total time=   0.0s
# [CV 3/5] END .max_depth=None, n_estimators=500;, score=-0.372 total time=   0.0s
# [CV 4/5] END ..max_depth=None, n_estimators=500;, score=0.539 total time=   0.1s
# [CV 5/5] END ..max_depth=None, n_estimators=500;, score=0.622 total time=   0.1s
# Best result: 0.501773 using the following hyperparameters {'max_depth': 2, 'n_estimators': 100}

# %%
#get the best parameters in the model
best_params = gsearch.best_params_

# %%
# predict the test dataset
final_model_v3 = RandomForestRegressor(**best_params)
final_model_v3.fit(X_train,y_train)
y_predict_v3 = final_model_v3.predict(X_test)

# %%
# Calculating MAE
MAE_minute_2_2 = mean_absolute_error(y_test, y_predict_v3)

# Calculating RMSE
MSE = mean_squared_error(y_test, y_predict_v3)
RMSE_minute_2_2 = np.sqrt(MSE)

print('Evaluation Metrics Results.....')
print('MAE: ', MAE_minute_2_2)
print('RMSE: ', RMSE_minute_2_2)
# Out:
# Evaluation Metrics Results.....
# MAE:  20.308702111924575
# RMSE:  23.024211276296082

# %% [markdown]
# ## Plot prediction

# %%
prediction_plot(y_test, y_predict_v3)

# %% [markdown]
# An interesting finding here is that the predicted price did not fall below 80 €/MWh. This could be due to model bias, which prevents it from capturing the low-price events.

# %% [markdown]
# Feature Importance

# %%
importances = final_model_v3.feature_importances_
features = final_model_v3.feature_names_in_

sns.barplot(x=importances, y=features, palette='RdBu')
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# ## Model 2 Linear Regression and XGB MAE and RMSE Scores

# %%
pd.set_option('display.max_colwidth', 100) 
MAE_RMSE_Scores = pd.DataFrame({'MAE':[MAE_minute_2,MAE_minute_2_2], 'RMSE':[RMSE_minute_2,RMSE_minute_2_2]}, index=['LR', 'XGB'])
MAE_RMSE_Scores
# Out:
#            MAE       RMSE
# LR   16.303686  18.103915
# XGB  20.308702  23.024211

# %% [markdown]
# The comparison of MAE and RMSE scores shows that the Linear Regression (LR) model performs well.

# %%
Pipleline_2 = make_pipeline(final_model_v2)
print(Pipleline_2.fit(X_train,y_train))
print(Pipleline_2.score(X_train,y_train))
print(Pipleline_2.score(X_test,y_test))
# Out:
# Pipeline(steps=[('linearregression',
#                  LinearRegression(fit_intercept=False, n_jobs=1))])
# 0.7971578473471882
# 0.10210379638663014

# %%
joblib.dump(final_model_v2,'Energy_price_prediction_v2')
# Out:
# ['Energy_price_prediction_v2']

# %% [markdown]
# # Optimization and Automation Concept

# %% [markdown]
# **Optimization**
#
# * Inputs: Predicted Energy Price
#
# * Variables
#
#     1. Decision variables: Charging power and discharging power
#     2. Defined variables: Charging and discharging efficiency of the thermal storage
#
# * Contraints:
#
#     1. Power Constraint: Keep the charging ahd discharging power of the thermal storage within the defined boundary limits.
#     2. State of Charge of the thermal Stoarge: Keep the thermal storage state of charge within its allowable boundary range.
#
# * Objective Function:
#
# Cost Minimization
#
# Minimization = Summation (Charging Power(t) * Market Spot price (Buying price) + operational cost) for t = 1 to T = 24
#
# **Logic**: Run the optimization every hour to determine the scheduled energy purchases for the next 24 hours, with the objective of minimizing cost.

# %% [markdown]
# **Real-Time Automation + ESIOS Integration**
#
# * 1. Get Real Time Data using an API
# * 2. Retrain Model
# * 3. Forecast Energy Price
# * 5. Solve Optimization Problem
# * 6. Send a control signal to the Thermal Energy Storage (TES) specifying the charging schedule for the next hour.
